# %%
import model_loader
import pipeline
from PIL import Image
from pathlib import Path
from transformers import CLIPTokenizer
import torch

DEVICE = "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print(f"Using device: {DEVICE}")

tokenizer = CLIPTokenizer("../data/vocab.json", merges_file="../data/merges.txt")
model_file = "../data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)

## TEXT TO IMAGE

#prompt = "A dog with sunglasses, wearing comfy hat, looking at camera, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
prompt = "A cat stretching on the floor, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
uncond_prompt = ""  # Also known as negative prompt
do_cfg = True
cfg_scale = 8  # min: 1, max: 14

## IMAGE TO IMAGE

input_image = None
# Comment to disable image to image
image_path = "../images/dog.jpg"
# input_image = Image.open(image_path)
# Higher values means more noise will be added to the input image, so the result will further from the input image.
# Lower values means less noise is added to the input image, so output will be closer to the input image.
strength = 0.9

## SAMPLER

sampler = "ddpm"
num_inference_steps = 50
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer,
)

# Combine the input image and the output image into a single image.
Image.fromarray(output_image)
# Out:
# C:\Users\i33238.AIR-WORLDWIDE\AppData\Local\Temp\ipykernel_10404\2401174200.py:15: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
# Using device: cpu
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [15:32<00:00, 18.65s/it]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
#pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.1.3-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17.2 in c:\python310\tf\lib\site-packages (from pytorch_lightning) (1.23.5)
# Requirement already satisfied: torch>=1.12.0 in c:\python310\tf\lib\site-packages (from pytorch_lightning) (2.1.1)
# Requirement already satisfied: tqdm>=4.57.0 in c:\python310\tf\lib\site-packages (from pytorch_lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in c:\python310\tf\lib\site-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\python310\tf\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.3.0.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=20.0 in c:\python310\tf\lib\site-packages (from pytorch_lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\python310\tf\lib\site-packages (from pytorch_lightning) (4.7.1)
# Collecting lightning-utilities>=0.8.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.10.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests in c:\python310\tf\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\python310\tf\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.8.5)
# Requirement already satisfied: setuptools in c:\python310\tf\lib\site-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (58.1.0)
# Requirement already satisfied: filelock in c:\python310\tf\lib\site-packages (from torch>=1.12.0->pytorch_lightning) (3.12.3)
# Requirement already satisfied: sympy in c:\python310\tf\lib\site-packages (from torch>=1.12.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in c:\python310\tf\lib\site-packages (from torch>=1.12.0->pytorch_lightning) (3.1)
# Requirement already satisfied: jinja2 in c:\python310\tf\lib\site-packages (from torch>=1.12.0->pytorch_lightning) (3.1.2)
# Requirement already satisfied: colorama in c:\python310\tf\lib\site-packages (from tqdm>=4.57.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: attrs>=17.3.0 in c:\python310\tf\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\python310\tf\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\python310\tf\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\python310\tf\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\python310\tf\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\python310\tf\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\python310\tf\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python310\tf\lib\site-packages (from jinja2->torch>=1.12.0->pytorch_lightning) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\tf\lib\site-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\tf\lib\site-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\tf\lib\site-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 